# %% [markdown]
# <a href="https://colab.research.google.com/github/Khaarl/VIZDOOM1/blob/main/VIZDOOM1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# --- Setup ---
# !apt-get update -y
# !apt-get install -y build-essential cmake git libboost-all-dev libsdl2-dev libjpeg-dev libpng-dev zlib1g-dev libpython3-dev

import os

# Use Mesa for software rendering (CPU-based)
os.environ['LIBGL_ALWAYS_SOFTWARE'] = '1'

# Set XDG_RUNTIME_DIR to avoid other SDL issues
os.environ['XDG_RUNTIME_DIR'] = '/tmp'
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,197 kB]
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,631 kB]
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,517 kB]
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# ...

# %%
# --- Install ViZDoom from source (for proper linking) ---
# !pip uninstall -y vizdoom
# !apt-get install -y libboost-python-dev
# !git clone https://github.com/mwydmuch/ViZDoom.git
# %cd ViZDoom
# !mkdir build && cd build
# !cmake .. -DBUILD_PYTHON=ON -DCMAKE_INSTALL_PREFIX=/usr/local
# !make -j$(nproc) install
# %cd /content
# !pip install vizdoom
# Out:
# WARNING: Skipping vizdoom as it is not installed.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libboost-python-dev is already the newest version (1.74.0.3ubuntu7).
# libboost-python-dev set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 47 not upgraded.
# Cloning into 'ViZDoom'...
# remote: Enumerating objects: 18734, done.
# remote: Counting objects: 100% (567/567), done.
# remote: Compressing objects: 100% (198/198), done.
# remote: Total 18734 (delta 469), reused 369 (delta 369), pack-reused 18167 (from 5)
# Receiving objects: 100% (18734/18734), 59.90 MiB | 20.74 MiB/s, done.
# Resolving deltas: 100% (11722/11722), done.
# /content/ViZDoom
# CMake Warning:
#   Ignoring extra path from command line:
#
#    ".."
#
#
# CMake Error: The source directory "/content" does not appear to contain CMakeLists.txt.
# Specify --help for usage, or press the help button on the CMake GUI.
# ...

# %%
# --- ViZDoom CPU-only Test ---
from vizdoom import *
import numpy as np
import time

# Create DoomGame instance
game = DoomGame()

# Load a basic scenario
game.load_config("/usr/local/lib/python3.10/dist-packages/vizdoom/scenarios/basic.cfg")  # Adjust path if needed

# Set screen format to a format that works well with CPU rendering
game.set_screen_format(ScreenFormat.RGB24)

# Disable window visibility (since we're using CPU rendering)
game.set_window_visible(False)

# Initialize the game
game.init()

# Get the available actions
actions = game.get_available_buttons()

# Run a few episodes
episodes = 10
for i in range(episodes):
    game.new_episode()
    while not game.is_episode_finished():
        state = game.get_state()
        n = state.number
        vars = state.game_variables
        screen_buffer = state.screen_buffer  # Get the rendered frame

        # Process the screen_buffer (it's a NumPy array) - e.g., display, analyze, etc.
        # ... (Your code to process the frame goes here) ...

        # Take a random action
        action = np.random.choice([0, 1], size=len(actions))
        reward = game.make_action(action.tolist())

        time.sleep(0.02)

    print("Episode #" + str(i + 1) + " finished with score: " + str(game.get_total_reward()))

game.close()
# Out:
# Episode #1 finished with score: -62.0
# Episode #2 finished with score: -385.0
# Episode #3 finished with score: -385.0
# Episode #4 finished with score: -390.0
# Episode #5 finished with score: -395.0
# Episode #6 finished with score: -380.0
# Episode #7 finished with score: -395.0
# Episode #8 finished with score: -380.0
# Episode #9 finished with score: -243.0
# Episode #10 finished with score: 95.0
